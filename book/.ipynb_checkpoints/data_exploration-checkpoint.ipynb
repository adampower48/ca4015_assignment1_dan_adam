# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_orl = pd.read_csv("data/parameter_igt_orl.csv")
df_orl["subjID_label"] = df_orl["subjID"].astype("category").cat.codes # number label for old/young
df_orl
# Out:
#     subjID        A+        A-         K     BetaF     BetaP     A+-A-  \
# 0      old  0.324444  0.068862  1.502130  2.523191 -5.547480  0.255581
# 1      old  0.885744  0.120145  0.012591  3.193244 -9.159800  0.765598
# 2      old  0.318205  0.078128  1.927309  0.615708  9.272336  0.240077
# 3      old  0.728192  0.106737  0.388407  2.595746 -2.239555  0.621455
# 4      old  0.356229  0.091987  1.810674  0.508605  9.825699  0.264241
# ..     ...       ...       ...       ...       ...       ...       ...
# 148  young  0.251484  0.120088  0.267192  1.809713 -1.857809  0.131396
# 149  young  0.073423  0.045859  1.127415  1.121871  2.031090  0.027564
# 150  young  0.249047  0.077884  0.911177  1.931949  0.964697  0.171163
# 151  young  0.106462  0.072973  0.455664  3.295131 -5.022590  0.033488
# 152  young  0.122015  0.122805  0.907778  1.077708  4.765409 -0.000790
#
#      subjID_label
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 148             1
# 149             1
# 150             1
# 151             1
# 152             1
#
# [153 rows x 8 columns]

# %% [markdown]
# # Paramters
# - A+: Reward Learning Rate
# - A-: Punishment Learning Rate
# - K: Decay
# - BetaF: Outcome freq
# - BetaP: Outcome perseverance

# %%
pd.plotting.scatter_matrix(df_orl[["A+", "A-", "K", "BetaF", "BetaP"]], figsize=(15,15), hist_kwds=dict(bins=50), c=df_orl["subjID_label"], cmap="Set1")
plt.show()
